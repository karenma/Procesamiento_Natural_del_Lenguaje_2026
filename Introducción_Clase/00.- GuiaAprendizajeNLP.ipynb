# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Procesamiento Natural del Lenguaje</h1>
#     <h3>Guía de Aprendizaje 2026</h3>
#
# </div>

# %% [markdown]
# <div style="text-align: right;">
# <img src="https://www.akamai.com/site/en/images/article/2025/what-is-nlp.png" width="350px" style="float: right; margin: 0px 0px 15px 15px;" />
# </div>
#
# ### <span style="color:#2E9AFE">Horarios</span>
# - **Viernes:** 17:00 a 21:00 hrs
# - **Sábados:** 9:00 a 13:00 hrs
#
# **Profesor:** <span style="color:#000047"><strong>Gaddiel Desirena López</strong></span>
# **Año:** 2026
# **Email:** <span style="color:blue">gdesirena@gmail.com</span>
#
# <hr style="border:1px solid #2E9AFE;">

# %% [markdown]
# ## 👨‍🏫 Presentación del Profesor
#
# ¡Hola! Soy Gaddiel Desirena López, apasionado por la Inteligencia Artificial y su aplicación en la vida real.
#
# - Tengo experiencia como científico de datos, experiencia en todo el ciclo de vida de los datos y desarrollo de algoritmos predictivos.
#
# - Formación académica: Doctorado y Maestría en Ingeniería Eléctrica (CINVESTAV-IPN).
#
# - Actualmente trabajo como ingeniero de Algoritmos en Continental Autonomous Mobility: desarrollo de modelos matemáticos de sensores (radares) y aplicación de inteligencia artificial para clasificación y detección.
#
# - Experiencia docente en inteligencia artificial y sistemas en tiempo real.

# %% [markdown]
# ## 🙋‍♂️ Presentación de los Estudiantes
#
# Por favor, comparte con el grupo:
# - Tu nombre y formación.
# - ¿Qué esperas aprender en este curso?
# - ¿Tienes experiencia previa con IA o programación?
# - Un dato curioso sobre ti.
#
# <hr>

# %% [markdown]
# ## 📜 Reglas de Convivencia y Participación
#
# 1. **Entrega de trabajos:** Todas las entregas se realizan a través de la plataforma [ALINNCO](https://digital.alinnco.mx/course/view.php?id=279) en los plazos asignados. No se aceptan trabajos fuera de la plataforma ni fuera de plazo.
# 2. **Participación activa:** Tu participación en clase es clave para el aprendizaje y puede influir en tu calificación final.
# 3. **Responsabilidad:** Revisa regularmente la plataforma para estar al tanto de avisos, materiales y fechas de entrega.
# 4. **Respeto:** Mantén siempre el respeto hacia tus compañeros y el profesor para un ambiente de trabajo óptimo.
# 5. **Comunicación:** Ante dudas o problemas, comunícate oportunamente con el profesor por los canales oficiales.

# %% [markdown]
# ## 🕑 Horario de Asesoría
#
# - **Solicita tu asesoría enviando un mensaje/correo con anticipación para coordinarnos.**
#
# <hr>

# %% [markdown]
# ## 📖 Descripción de la Asignatura
#
# El Procesamiento del Lenguaje Natural o **NLP** es una disciplina que se encuentra en la intersección de varias ciencias, tales como las Ciencias de la Computación, la Inteligencia Artificial y Psicología Cognitiva.
# > Su idea central es la de darle a las máquinas la capacidad de leer y comprender los idiomas que hablamos los humanos. La investigación del Procesamiento del Lenguaje Natural tiene como objetivo responder a la pregunta de cómo las personas son capaces de comprender el significado de una oración oral / escrita y cómo las personas entienden lo que sucedió, cuándo y dónde sucedió; y las diferencias entre una suposición, una creencia o un hecho.
#
# <hr>

# %% [markdown]
# ## 🎯 Objetivos del Curso
#
# | Objetivo General | Objetivos Específicos |
# |------------------|----------------------|
# | Introducir al análisis y transformación del lenguaje mediante técnicas computacionales. Representar al texto y discurso que pueden ayudar a la predicción, la extracción y el razonamiento semántico sobre el lenguaje. Comprender el lenguaje natural para su aplicación en los hardwares y software. | <br>- Desarrollar un claro entendimiento del flujo de trabajo requerido por proyectos de NLP con aprendizaje automático.<br>- Estar en capacidad de aplicar el paradigma de aprendizaje supervisado a problemas de NLP.<br>- Conocer la problemática y las principales aplicaciones del aprendizaje automático al NLP.|
#
# <hr>

# %% [markdown]
# ## 🗂️ Contenido Temático
#
# <details>
# <summary><strong>Introducción a NLP</strong></summary>
# <ul>
# <li>Guía de aprendizaje</li>
# <li>Herramientas computacionales</li>
# <li>Fundamentos</li>
#      <ul>
#         <li>¿Qué es el NLP y sus aplicaciones?</li>
#         <li>Conceptos clave: tokens, corpus, vocabulario</li>
#         <li>Embeddings: intuición y uso</li>
#         <li>Pipeline típico de un proyecto NLP</li>
#         <li>Configuración del entorno (conda / venv)</li>
#     </ul>
# <li>Herramientas base</li>
#      <ul>
#         <li>Introducción a NLTK y spaCy</li>
#         <li>Manejo de texto con `re` y `string`</li>
#         <li>Exploración de un corpus real</li>
#         <li>Ejercicio limpieza y preprocesamiento básico</li>
#         <li>Q&A y dudas de instalación</li>
#     </ul>
#
# </ul>
# </details>
#
#
# <details>
# <summary><strong>Módulo 1: Preprocesamiento y Representación de Texto</strong></summary>
# <ul>
# <li>Procesamiento y Transformaciones de texto</li>
#      <ul>
#         <li>Tokenización a nivel palabra y oración</li>
#         <li>Stemming (PorterStemmer, SnowballStemmer)</li>
#         <li>Lematización con spaCy y NLTK</li>
#         <li>Diferencias entre stemming y lematización</li>
#         <li>Stopwords</li>
#     </ul>
# <li>Limpieza y normalización</li>
#      <ul>
#         <li>Eliminación de stopwords</li>
#         <li>Expresiones regulares para texto (`re`)</li>
#         <li>Normalización: minúsculas, puntuación, acentos</li>
#         <li>Construcción de un pipeline de limpieza</li>
#         <li>Ejercicio preprocesar corpus de noticias</li>
#     </ul>
# <li>Representación vectorial de textos</li>
#      <ul>
#         <li>Bag of Words (BoW): construcción y limitaciones</li>
#         <li>TF-IDF: cálculo e interpretación</li>
#         <li>Visualización de matrices de términos</li>
#     </ul>
# <li>Word Embeddings</li>
#      <ul>
#         <li>Word2Vec: CBOW vs Skip-gram</li>
#         <li>Sentence embeddings (`sentence-transformers`)</li>
#         <li>Ejercicio: similitud semántica con Word2Vec</li>
#     </ul>
# </ul>
# </details>
#
# <details>
# <summary><strong>Módulo 2: Tareas Clásicas de NLP</strong></summary>
# <ul>
# <li>Clasificación de texto</li>
#     <ul>
#         <li>Análisis de sentimientos (positivo / negativo / neutro)</li>
#         <li>Clasificación multi-clase de documentos</li>
#         <li>Modelos: Naive Bayes, SVM, Logistic Regression</li>
#     </ul>
# <li>Extracción de información</li>
#     <ul>
#         <li>Named Entity Recognition (NER)</li>
#         <li>Part-of-Speech Tagging (POS)</li>
#         <li>Extracción de keywords y relaciones</li>
#     </ul>
# </ul>
# </details>
#
# <details>
# <summary><strong>Módulo 3: Modelos de Lenguaje y Etiquetado de Secuencia.</strong></summary>
# <ul>
# <li>Arquitectura Transformer</li>
#     <ul>
#     <li>Mecanismo de atención (Self-Attention)</li>
#     <li>Encoders y Decoders</li>
#     <li>BERT y RoBERTa: modelos pre-entrenados</li>
#     <li>Fine-tuning para tareas específicas</li>
#     </ul>
# </ul>
# </details>
#
# <hr>

# %% [markdown]
# ## 📝 Evaluación
#
# | Actividad         | Porcentaje |
# |-------------------|:----------:|
# | Tareas            |   30%      |
# | Actividades       |   30%      |
# | Proyecto Final    |   40%      |
#
# <hr>

# %% [markdown]
# ## 👨‍🏫 Descanso entre sesiones
# #### 7-7.30 descanso **Viernes**
# #### 11-11.30 descanso **Sábados**

# %% [markdown]
# ## 📚 Bibliografía y Recursos Recomendados
# - *Speech and Language Processing* — Jurafsky & Martin (Cap. 1-2)
# - [NLTK Book](https://www.nltk.org/book/) — Capítulo 1
# - Documentación oficial de spaCy: https://spacy.io
# - *NLP with Python* — Bird, Klein & Loper (Cap. 3)
# - Mikolov et al. (2013) — *Efficient Estimation of Word Representations in Vector Space*
# - [Gensim Word2Vec Tutorial](https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html)
# - [scikit-learn Text Classification Guide](https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html)
# - *NLP with Python* — Bird, Klein & Loper (Cap. 5-7)
# - Documentación de stanza: https://stanfordnlp.github.io/stanza
# - Vaswani et al. (2017) — *Attention Is All You Need*
# - [Hugging Face NLP Course](https://huggingface.co/learn/nlp-course) — Capítulos 1-4
# - *Natural Language Processing with Transformers* — Tunstall, von Werra & Wolf
#
#
# **Recursos adicionales:**
#
# | Library | Description | Link |
# |---|---|---|
# | `NLTK` | Natural Language Toolkit — tokenization, stemming, lemmatization, stopwords | [nltk.org](https://www.nltk.org/) |
# | `spaCy` | Industrial-strength NLP — lemmatization, NER, POS tagging | [spacy.io](https://spacy.io/) |
# | `re` | Python built-in regex module | [docs.python.org/re](https://docs.python.org/3/library/re.html) |
# | `string` | Python built-in string utilities | [docs.python.org/string](https://docs.python.org/3/library/string.html) |
# | `scikit-learn` | BoW, TF-IDF, Naive Bayes, SVM, Logistic Regression | [scikit-learn.org](https://scikit-learn.org/) |
# | `pandas` | Data manipulation and analysis | [pandas.pydata.org](https://pandas.pydata.org/) |
# | `numpy` | Numerical computing | [numpy.org](https://numpy.org/) |
# | `gensim` | Word2Vec, GloVe, FastText embeddings | [radimrehurek.com/gensim](https://radimrehurek.com/gensim/) |
# | `sentence-transformers` | Sentence embeddings and semantic similarity | [sbert.net](https://www.sbert.net/) |
# | `transformers` | Hugging Face — BERT, RoBERTa, fine-tuning | [huggingface.co/docs/transformers](https://huggingface.co/docs/transformers) |
# | `torch` | PyTorch — deep learning backend | [pytorch.org](https://pytorch.org/) |
# | `datasets` | Hugging Face datasets library | [huggingface.co/docs/datasets](https://huggingface.co/docs/datasets) |
# | `FastAPI` | API deployment framework | [fastapi.tiangolo.com](https://fastapi.tiangolo.com/) |
# | `Gradio` | Quick ML model UI deployment | [gradio.app](https://www.gradio.app/) |
# | `stanza` | Stanford NLP — deep learning NLP pipeline | [stanfordnlp.github.io/stanza](https://stanfordnlp.github.io/stanza/) |
# <hr>
